# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/DACON_PLANT"
# Out:
# /content/drive/MyDrive/Colab Notebooks/DACON_PLANT

# %%
# %matplotlib inline

# %%
# !bash run.sh

# %%
# !python main.py --learning_rate 0.002 --batch_size 8 --epochs 10
# Out:
# start
# ===== [ 모델 학습 정보 (1652158801.6283295) ] =====
# train_data: 100% 75/75 [00:00<00:00, 266.40it/s]
# data loaded
# train len :  1273 validation len :  319
# model : CNNRegressor
#   9% 14/160 [03:58<41:17, 16.97s/it]

# %%
# !python test.py
# Out:
# yes

# %%
# !python main.py
# Out:
# start
# ===== [ 모델 학습 정보 (1651232812.160088) ] =====
# train_data: 100% 75/75 [00:00<00:00, 194.85it/s]
# data loaded
# train len :  1273 validation len :  319
# model : CNNRegressor
# 100% 160/160 [17:35<00:00,  6.59s/it]
# 100% 40/40 [04:26<00:00,  6.65s/it]
# Epoch [1] Train MAE : [80.16487] Validation MAE : [81.52971]
#
# Model Saved.
# 100% 160/160 [05:06<00:00,  1.92s/it]
# 100% 40/40 [01:16<00:00,  1.91s/it]
# Epoch [2] Train MAE : [80.14124] Validation MAE : [81.44280]
#
# Model Saved.
# 100% 160/160 [05:05<00:00,  1.91s/it]
# 100% 40/40 [01:16<00:00,  1.92s/it]
# Epoch [3] Train MAE : [80.11344] Validation MAE : [81.33213]
#
# Model Saved.
# 100% 160/160 [05:03<00:00,  1.90s/it]
# 100% 40/40 [01:15<00:00,  1.90s/it]
# Epoch [4] Train MAE : [81.85038] Validation MAE : [81.16812]
#
# Model Saved.
# 100% 160/160 [05:05<00:00,  1.91s/it]
# 100% 40/40 [01:16<00:00,  1.91s/it]
# Epoch [5] Train MAE : [79.83771] Validation MAE : [80.87667]
#
# Model Saved.
# ...

# %%
f = open("result.csv", 'w')
f.write('a')
f.write("\n")
f.write('b')
f.write("\n")
f.write('c')
f.write("\n")
f.close()
